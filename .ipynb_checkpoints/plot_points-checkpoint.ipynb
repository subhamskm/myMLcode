# %%
import matplotlib.pyplot

# %%
x=[2,6]
y=[3,4]
x1=[8,3]
y1=[4,7]
plt.xlabel("Time")
plt.ylabel("Speed")
plt.plot(x,y,label="river")
plt.plot(x1,y1,label="railway")
plt.legend()
plt.grid(color='y')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=[200,60,34,90]
y=["Virat","Dhoni","Sachin","Yuvi"]
x1=[80,67,90,10]
y1=["rr","helo","go","nice"]
plt.bar(y,x,label="A")
plt.bar(y1,x1,label="B")
plt.legend()
plt.grid(color='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=[2,6,5,6,7,78,8]
y=[4,9,23,6,9,6,5]
plt.scatter(x,y,label="mines",marker='x')
x1=[1,2,3,4,5,6,7]
y1=[5,3,2,5,7,4,3]
plt.scatter(x1,y1,label="water",s=100)
plt.legend()

# %%
whoami
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-7a186a3a7604> in <module>()
# ----> 1 whoami
#
# NameError: name 'whoami' is not defined

# %%
which python
# Out:
#   File "<ipython-input-28-d8603f9f9bc3>", line 1
#     which python
#                ^
# SyntaxError: invalid syntax

# %%
import os
os.system("echo hello friend | festival --tts")
# Out:
# 0

# %%
#!/usr/bin/env python3
# Requires PyAudio and PySpeech.
 
import speech_recognition as sr
 
# Record Audio
r = sr.Recognizer()
with sr.Microphone() as source:
    print("Say something!")
    audio = r.listen(source)
 
# Speech recognition using Google Speech Recognition
try:
    # for testing purposes, we're just using the default API key
    # to use another API key, use `r.recognize_google(audio, key="GOOGLE_SPEECH_RECOGNITION_API_KEY")`
    # instead of `r.recognize_google(audio)`
    print("You said: " + r.recognize_google(audio))
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
except sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service; {0}".format(e))

# %%
import matplotlib.pyplot as plt

x=[3,4,11]
y=[8,6,12]
plt.plot(x,y)
plt.show()

# %%
import speech_recognition as sr
import matplotlib.pyplot as plt
import os

def plot(u,v):
   plt.plot(u,v)
   plt.show
   

r=sr.Recognizer()
with sr.Microphone() as source:
    print ("Say the line \'plot the points _, _ and _, _ \' with the corressponding points replacing _: ")
    audio = r.listen(source)

try:
    str=r.recognize_google(audio)
    s=str.split()
    x=int(s[3][0:-1])
    y=int(s[4])
    a=int(s[6][0:-1])
    b=int(s[7])
    plot([x,a],[y,b])
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
except sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service;{0}".format(e))
# Out:
# Say the line 'plot the points _, _ and _, _ ' with the corressponding points replacing _:
# Could not request results from Google Speech Recognition service;recognition connection failed: [Errno 32] Broken pipe
